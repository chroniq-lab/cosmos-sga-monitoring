# %%
import sys
import os
execfile("C:/code/external/functions/cosmos/code_splitter.py")
code_splitter("C:/Cloud/OneDrive - Emory University/Papers/COSMOS SGA T2DM Monitoring/working/cosmos/sga_dm_control.txt",
              "C:/code/external/cosmos-sga-monitoring")
